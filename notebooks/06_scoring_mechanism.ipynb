# %%
# ============================================
# CELL 6: Pre-defined Job Descriptions Database
# ============================================

JOB_DATABASE = {
    "Software Engineer - Python": """
    We are looking for a Software Engineer proficient in Python programming.
    Required skills: Python, Django or Flask, SQL, REST APIs, Git.
    Experience with cloud platforms (AWS/GCP) is a plus.
    Strong problem-solving and communication skills required.
    """,
    
    "Data Scientist": """
    Seeking an experienced Data Scientist with expertise in Machine Learning.
    Required: Python, pandas, scikit-learn, TensorFlow or PyTorch.
    Knowledge of statistics, data visualization (Tableau/Power BI).
    Experience with SQL and big data technologies (Spark) preferred.
    """,
    
    "Java Backend Developer": """
    Hiring Java Backend Engineer with Spring Boot experience.
    Must have: Java 8+, Spring Boot, Microservices, REST APIs, Maven/Gradle.
    Database skills: MySQL/PostgreSQL, Hibernate/JPA.
    Familiarity with Docker and Kubernetes is advantageous.
    """,
    
    "Frontend React Developer": """
    Looking for Frontend Developer specializing in React.
    Required: JavaScript/ES6, React.js, Redux, HTML5, CSS3.
    Experience with responsive design and REST API integration.
    Knowledge of Next.js or TypeScript is a plus.
    """,
    
    "DevOps Engineer": """
    Seeking DevOps Engineer with cloud infrastructure experience.
    Required: AWS/Azure, Docker, Kubernetes, CI/CD pipelines (Jenkins/GitLab).
    Scripting skills: Python or Bash. Infrastructure as Code (Terraform).
    Monitoring tools: Prometheus, Grafana.
    """,
    
    "Machine Learning Engineer": """
    Hiring Machine Learning Engineer for AI projects.
    Required: Python, TensorFlow/PyTorch, scikit-learn, deep learning.
    Experience with computer vision or NLP.
    Knowledge of MLOps and model deployment.
    """,
    
    "Full Stack Developer": """
    Looking for Full Stack Developer with versatile skills.
    Frontend: React/Angular, HTML/CSS, JavaScript.
    Backend: Node.js/Python/Django, REST APIs.
    Database: MongoDB/PostgreSQL.
    Version control: Git. Cloud deployment experience preferred.
    """,
    
    "Data Analyst": """
    Seeking Data Analyst for business intelligence.
    Required: SQL, Excel, Tableau/Power BI, Python/pandas.
    Statistics knowledge and data visualization skills.
    Strong communication and presentation abilities.
    """
}

def get_all_job_titles():
    """Return list of available job titles"""
    return list(JOB_DATABASE.keys())

def get_job_description(job_title):
    """Get job description by title"""
    return JOB_DATABASE.get(job_title, "")

print(f"✅ Job database loaded with {len(JOB_DATABASE)} positions")
print(f"Available jobs: {', '.join(get_all_job_titles())}")
# Out:
# ✅ Job database loaded with 8 positions
# Available jobs: Software Engineer - Python, Data Scientist, Java Backend Developer, Frontend React Developer, DevOps Engineer, Machine Learning Engineer, Full Stack Developer, Data Analyst
